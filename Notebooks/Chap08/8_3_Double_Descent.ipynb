# %% [markdown]
# <a href="https://colab.research.google.com/github/uezhenxiang2023/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-ve4lhlly
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-ve4lhlly
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (2.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=2901cc9f5b7a704b7767d6eb312e11fbca739c362d0d9e92f2eddcdec66e83a2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f88fk6rv/wheels/33/99/c5/794fea38f039adfbca82fd56e4a00b3e1e4533a808baee9910
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.297045, train error 87.82,  test loss 2.298907, test error 88.47
# Epoch   100, train loss 1.859910, train error 70.85,  test loss 1.699862, test error 68.35
# Epoch   200, train loss 1.856644, train error 69.75,  test loss 1.703298, test error 67.60
# Epoch   300, train loss 1.850517, train error 70.03,  test loss 1.695387, test error 68.10
# Epoch   400, train loss 1.850228, train error 69.55,  test loss 1.697374, test error 67.80
# Epoch   500, train loss 1.859742, train error 70.95,  test loss 1.702657, test error 68.50
# Epoch   600, train loss 1.867403, train error 70.25,  test loss 1.711939, test error 68.43
# Epoch   700, train loss 1.858548, train error 70.75,  test loss 1.698755, test error 67.38
# Epoch   800, train loss 1.848797, train error 70.32,  test loss 1.691316, test error 67.70
# Epoch   900, train loss 1.852431, train error 70.22,  test loss 1.687379, test error 68.03
# Training model with   4 hidden variables
# Epoch     0, train loss 2.195229, train error 81.15,  test loss 2.160247, test error 80.12
# Epoch   100, train loss 1.840475, train error 69.55,  test loss 1.683177, test error 67.45
# Epoch   200, train loss 1.785959, train error 66.75,  test loss 1.610506, test error 63.60
# Epoch   300, train loss 1.763562, train error 65.18,  test loss 1.584717, test error 61.00
# Epoch   400, train loss 1.706475, train error 61.85,  test loss 1.521073, test error 58.65
# Epoch   500, train loss 1.689233, train error 61.28,  test loss 1.505672, test error 57.88
# Epoch   600, train loss 1.687827, train error 60.15,  test loss 1.502923, test error 56.72
# Epoch   700, train loss 1.683619, train error 60.80,  test loss 1.505590, test error 57.95
# Epoch   800, train loss 1.682851, train error 60.42,  test loss 1.510513, test error 57.95
# Epoch   900, train loss 1.678784, train error 60.92,  test loss 1.502850, test error 57.58
# Training model with   6 hidden variables
# Epoch     0, train loss 2.257464, train error 87.40,  test loss 2.254179, test error 86.88
# Epoch   100, train loss 1.726071, train error 62.90,  test loss 1.600358, test error 62.50
# Epoch   200, train loss 1.640918, train error 58.20,  test loss 1.479144, test error 56.38
# Epoch   300, train loss 1.597225, train error 56.53,  test loss 1.428138, test error 54.33
# Epoch   400, train loss 1.588634, train error 55.88,  test loss 1.419326, test error 53.95
# Epoch   500, train loss 1.573509, train error 54.88,  test loss 1.415563, test error 53.70
# Epoch   600, train loss 1.563347, train error 54.38,  test loss 1.413930, test error 53.40
# Epoch   700, train loss 1.561779, train error 54.80,  test loss 1.423299, test error 54.17
# Epoch   800, train loss 1.559041, train error 54.53,  test loss 1.422697, test error 54.65
# Epoch   900, train loss 1.558193, train error 54.90,  test loss 1.421929, test error 53.92
# Training model with   8 hidden variables
# Epoch     0, train loss 2.287609, train error 86.40,  test loss 2.281242, test error 86.68
# Epoch   100, train loss 1.616670, train error 58.65,  test loss 1.450734, test error 56.60
# Epoch   200, train loss 1.570626, train error 55.95,  test loss 1.431877, test error 55.78
# Epoch   300, train loss 1.566147, train error 55.83,  test loss 1.453107, test error 56.35
# Epoch   400, train loss 1.553658, train error 55.08,  test loss 1.446615, test error 56.22
# Epoch   500, train loss 1.546703, train error 55.10,  test loss 1.460603, test error 56.05
# Epoch   600, train loss 1.550109, train error 55.08,  test loss 1.466539, test error 56.78
# Epoch   700, train loss 1.551677, train error 55.72,  test loss 1.471558, test error 56.62
# Epoch   800, train loss 1.546849, train error 55.55,  test loss 1.473930, test error 56.78
# Epoch   900, train loss 1.545609, train error 54.67,  test loss 1.467484, test error 56.88
# Training model with  10 hidden variables
# Epoch     0, train loss 2.207831, train error 84.78,  test loss 2.186761, test error 84.20
# Epoch   100, train loss 1.492555, train error 51.65,  test loss 1.332662, test error 49.60
# Epoch   200, train loss 1.452386, train error 50.53,  test loss 1.322358, test error 48.90
# Epoch   300, train loss 1.442398, train error 50.35,  test loss 1.340438, test error 49.97
# Epoch   400, train loss 1.430205, train error 50.03,  test loss 1.355753, test error 50.50
# Epoch   500, train loss 1.421661, train error 49.67,  test loss 1.360418, test error 49.58
# Epoch   600, train loss 1.417351, train error 49.38,  test loss 1.380358, test error 49.30
# Epoch   700, train loss 1.407392, train error 48.88,  test loss 1.370800, test error 49.28
# Epoch   800, train loss 1.405912, train error 49.72,  test loss 1.371012, test error 49.60
# Epoch   900, train loss 1.406761, train error 49.28,  test loss 1.382454, test error 50.20
# Training model with  14 hidden variables
# Epoch     0, train loss 2.220716, train error 82.00,  test loss 2.197767, test error 80.90
# Epoch   100, train loss 1.440148, train error 48.97,  test loss 1.338334, test error 50.38
# Epoch   200, train loss 1.358864, train error 45.95,  test loss 1.305399, test error 48.20
# Epoch   300, train loss 1.319896, train error 45.05,  test loss 1.310033, test error 47.33
# Epoch   400, train loss 1.304833, train error 44.92,  test loss 1.320788, test error 48.55
# Epoch   500, train loss 1.285802, train error 43.58,  test loss 1.342398, test error 49.28
# Epoch   600, train loss 1.280045, train error 42.60,  test loss 1.356289, test error 49.55
# Epoch   700, train loss 1.273749, train error 43.70,  test loss 1.370433, test error 49.60
# Epoch   800, train loss 1.260867, train error 42.00,  test loss 1.388732, test error 49.85
# Epoch   900, train loss 1.260900, train error 42.95,  test loss 1.399941, test error 50.47
# Training model with  18 hidden variables
# Epoch     0, train loss 2.234939, train error 82.15,  test loss 2.224890, test error 81.38
# Epoch   100, train loss 1.333828, train error 44.53,  test loss 1.263017, test error 46.78
# Epoch   200, train loss 1.247580, train error 41.80,  test loss 1.293712, test error 47.83
# Epoch   300, train loss 1.207317, train error 40.38,  test loss 1.350341, test error 49.35
# Epoch   400, train loss 1.165282, train error 39.97,  test loss 1.381188, test error 49.47
# Epoch   500, train loss 1.153578, train error 39.17,  test loss 1.411312, test error 49.03
# Epoch   600, train loss 1.139314, train error 39.12,  test loss 1.450661, test error 50.55
# Epoch   700, train loss 1.131082, train error 37.92,  test loss 1.450494, test error 49.70
# Epoch   800, train loss 1.122701, train error 37.72,  test loss 1.475963, test error 49.62
# Epoch   900, train loss 1.114256, train error 37.62,  test loss 1.524771, test error 50.38
# Training model with  22 hidden variables
# Epoch     0, train loss 2.206827, train error 81.35,  test loss 2.196394, test error 81.20
# Epoch   100, train loss 1.291071, train error 42.47,  test loss 1.342305, test error 50.50
# Epoch   200, train loss 1.161056, train error 38.03,  test loss 1.380622, test error 49.72
# Epoch   300, train loss 1.101046, train error 36.25,  test loss 1.441434, test error 50.33
# Epoch   400, train loss 1.076857, train error 35.43,  test loss 1.507968, test error 50.95
# Epoch   500, train loss 1.057078, train error 35.05,  test loss 1.547006, test error 51.45
# Epoch   600, train loss 1.036209, train error 34.47,  test loss 1.576114, test error 51.92
# Epoch   700, train loss 1.041615, train error 35.18,  test loss 1.642403, test error 51.92
# Epoch   800, train loss 1.024050, train error 34.12,  test loss 1.669963, test error 52.25
# Epoch   900, train loss 1.012033, train error 33.68,  test loss 1.726421, test error 52.55
# Training model with  26 hidden variables
# Epoch     0, train loss 2.184685, train error 80.78,  test loss 2.166686, test error 80.32
# Epoch   100, train loss 1.173389, train error 37.70,  test loss 1.237353, test error 45.97
# Epoch   200, train loss 1.049102, train error 33.95,  test loss 1.363579, test error 48.97
# Epoch   300, train loss 0.967689, train error 31.55,  test loss 1.487221, test error 50.62
# Epoch   400, train loss 0.931471, train error 31.10,  test loss 1.595947, test error 52.00
# Epoch   500, train loss 0.910957, train error 30.05,  test loss 1.683598, test error 52.33
# Epoch   600, train loss 0.883744, train error 29.18,  test loss 1.751947, test error 53.08
# Epoch   700, train loss 0.863289, train error 28.55,  test loss 1.848048, test error 54.05
# Epoch   800, train loss 0.858837, train error 29.03,  test loss 1.864380, test error 52.62
# Epoch   900, train loss 0.831137, train error 28.25,  test loss 1.959759, test error 53.72
# Training model with  30 hidden variables
# Epoch     0, train loss 2.155288, train error 80.07,  test loss 2.108999, test error 78.68
# Epoch   100, train loss 1.098614, train error 35.97,  test loss 1.339665, test error 48.30
# Epoch   200, train loss 0.923038, train error 30.88,  test loss 1.503032, test error 49.80
# Epoch   300, train loss 0.828485, train error 27.32,  test loss 1.734432, test error 52.72
# Epoch   400, train loss 0.804873, train error 27.10,  test loss 1.928982, test error 53.60
# Epoch   500, train loss 0.751845, train error 26.15,  test loss 2.039160, test error 53.50
# Epoch   600, train loss 0.730468, train error 25.22,  test loss 2.203503, test error 53.95
# Epoch   700, train loss 0.709704, train error 24.65,  test loss 2.344782, test error 53.53
# Epoch   800, train loss 0.692866, train error 23.55,  test loss 2.486521, test error 54.62
# Epoch   900, train loss 0.656133, train error 22.88,  test loss 2.606824, test error 54.33
# Training model with  35 hidden variables
# Epoch     0, train loss 2.059683, train error 75.85,  test loss 1.972066, test error 74.88
# Epoch   100, train loss 1.005495, train error 31.82,  test loss 1.363102, test error 49.53
# Epoch   200, train loss 0.778981, train error 25.25,  test loss 1.611231, test error 50.80
# Epoch   300, train loss 0.702377, train error 23.55,  test loss 1.997343, test error 54.20
# Epoch   400, train loss 0.588915, train error 19.47,  test loss 2.228896, test error 53.12
# Epoch   500, train loss 0.546624, train error 18.40,  test loss 2.532417, test error 54.00
# Epoch   600, train loss 0.529794, train error 18.22,  test loss 2.828266, test error 54.97
# Epoch   700, train loss 0.490615, train error 17.20,  test loss 3.091882, test error 54.40
# Epoch   800, train loss 0.455276, train error 15.38,  test loss 3.375004, test error 54.72
# Epoch   900, train loss 0.485481, train error 17.50,  test loss 3.699758, test error 56.58
# Training model with  40 hidden variables
# Epoch     0, train loss 2.070627, train error 78.12,  test loss 2.005158, test error 77.45
# Epoch   100, train loss 0.907123, train error 28.68,  test loss 1.433428, test error 49.10
# Epoch   200, train loss 0.651933, train error 21.18,  test loss 1.885708, test error 51.88
# Epoch   300, train loss 0.485891, train error 15.20,  test loss 2.443114, test error 53.83
# Epoch   400, train loss 0.453255, train error 15.78,  test loss 3.142784, test error 55.67
# Epoch   500, train loss 0.364188, train error 12.70,  test loss 3.748402, test error 55.83
# Epoch   600, train loss 0.273701, train error 9.07,  test loss 4.420478, test error 56.33
# Epoch   700, train loss 0.238648, train error 7.95,  test loss 5.181082, test error 56.40
# Epoch   800, train loss 0.224049, train error 7.97,  test loss 5.972672, test error 57.33
# Epoch   900, train loss 0.258921, train error 9.78,  test loss 6.639408, test error 57.97
# Training model with  45 hidden variables
# Epoch     0, train loss 2.158618, train error 79.20,  test loss 2.143758, test error 79.68
# Epoch   100, train loss 0.824207, train error 26.32,  test loss 1.660286, test error 53.85
# Epoch   200, train loss 0.499800, train error 16.12,  test loss 2.487677, test error 54.88
# Epoch   300, train loss 0.309543, train error 9.57,  test loss 3.690514, test error 56.67
# Epoch   400, train loss 0.228880, train error 7.25,  test loss 5.088889, test error 57.85
# Epoch   500, train loss 0.244256, train error 8.62,  test loss 6.484696, test error 57.97
# Epoch   600, train loss 0.068786, train error 1.35,  test loss 7.863872, test error 57.90
# Epoch   700, train loss 0.096140, train error 2.82,  test loss 8.774216, test error 57.03
# Epoch   800, train loss 0.008750, train error 0.00,  test loss 9.762279, test error 57.80
# Epoch   900, train loss 0.006053, train error 0.00,  test loss 10.364588, test error 57.88
# Training model with  50 hidden variables
# Epoch     0, train loss 2.112286, train error 77.43,  test loss 2.079319, test error 77.55
# Epoch   100, train loss 0.694879, train error 20.78,  test loss 1.579654, test error 51.03
# Epoch   200, train loss 0.328851, train error 9.40,  test loss 2.616271, test error 53.40
# Epoch   300, train loss 0.143368, train error 3.20,  test loss 4.159791, test error 55.45
# Epoch   400, train loss 0.034128, train error 0.05,  test loss 5.722658, test error 55.75
# Epoch   500, train loss 0.013697, train error 0.00,  test loss 6.677333, test error 55.17
# Epoch   600, train loss 0.008813, train error 0.00,  test loss 7.322271, test error 55.42
# Epoch   700, train loss 0.006234, train error 0.00,  test loss 7.811904, test error 55.67
# Epoch   800, train loss 0.004801, train error 0.00,  test loss 8.183789, test error 55.47
# Epoch   900, train loss 0.003837, train error 0.00,  test loss 8.499210, test error 55.45
# Training model with  55 hidden variables
# Epoch     0, train loss 2.063719, train error 77.38,  test loss 2.021405, test error 78.05
# Epoch   100, train loss 0.608350, train error 17.55,  test loss 1.639584, test error 49.95
# Epoch   200, train loss 0.199092, train error 4.62,  test loss 3.066569, test error 54.30
# Epoch   300, train loss 0.036342, train error 0.03,  test loss 4.767668, test error 54.83
# Epoch   400, train loss 0.013620, train error 0.00,  test loss 5.753072, test error 54.95
# Epoch   500, train loss 0.007860, train error 0.00,  test loss 6.366820, test error 54.97
# Epoch   600, train loss 0.005422, train error 0.00,  test loss 6.790104, test error 54.88
# Epoch   700, train loss 0.004073, train error 0.00,  test loss 7.127892, test error 54.85
# Epoch   800, train loss 0.003231, train error 0.00,  test loss 7.403144, test error 54.85
# Epoch   900, train loss 0.002660, train error 0.00,  test loss 7.635685, test error 54.83
# Training model with  60 hidden variables
# Epoch     0, train loss 2.060403, train error 77.22,  test loss 2.039910, test error 77.40
# Epoch   100, train loss 0.538267, train error 16.25,  test loss 1.814580, test error 52.88
# Epoch   200, train loss 0.109241, train error 0.90,  test loss 3.445593, test error 54.03
# Epoch   300, train loss 0.021253, train error 0.00,  test loss 4.844274, test error 55.15
# Epoch   400, train loss 0.010000, train error 0.00,  test loss 5.577838, test error 55.35
# Epoch   500, train loss 0.006209, train error 0.00,  test loss 6.034631, test error 55.33
# Epoch   600, train loss 0.004419, train error 0.00,  test loss 6.382215, test error 55.33
# Epoch   700, train loss 0.003414, train error 0.00,  test loss 6.663525, test error 55.67
# Epoch   800, train loss 0.002719, train error 0.00,  test loss 6.881615, test error 55.60
# Epoch   900, train loss 0.002255, train error 0.00,  test loss 7.077934, test error 55.80
# Training model with  70 hidden variables
# Epoch     0, train loss 2.005818, train error 73.43,  test loss 1.934157, test error 73.60
# Epoch   100, train loss 0.335146, train error 7.78,  test loss 2.066578, test error 52.35
# Epoch   200, train loss 0.032458, train error 0.00,  test loss 3.812593, test error 53.80
# Epoch   300, train loss 0.010948, train error 0.00,  test loss 4.668098, test error 54.38
# Epoch   400, train loss 0.006091, train error 0.00,  test loss 5.149550, test error 54.50
# Epoch   500, train loss 0.004102, train error 0.00,  test loss 5.481570, test error 54.72
# Epoch   600, train loss 0.003042, train error 0.00,  test loss 5.733722, test error 54.80
# Epoch   700, train loss 0.002387, train error 0.00,  test loss 5.936879, test error 54.58
# Epoch   800, train loss 0.001951, train error 0.00,  test loss 6.107926, test error 54.72
# Epoch   900, train loss 0.001639, train error 0.00,  test loss 6.253278, test error 54.60
# Training model with  80 hidden variables
# Epoch     0, train loss 1.978723, train error 74.55,  test loss 1.922821, test error 76.03
# Epoch   100, train loss 0.223048, train error 3.78,  test loss 2.124458, test error 51.38
# Epoch   200, train loss 0.019100, train error 0.00,  test loss 3.474730, test error 52.38
# Epoch   300, train loss 0.007715, train error 0.00,  test loss 4.029700, test error 52.58
# Epoch   400, train loss 0.004576, train error 0.00,  test loss 4.364841, test error 52.67
# Epoch   500, train loss 0.003167, train error 0.00,  test loss 4.600211, test error 52.85
# Epoch   600, train loss 0.002391, train error 0.00,  test loss 4.784397, test error 52.85
# Epoch   700, train loss 0.001903, train error 0.00,  test loss 4.932646, test error 52.92
# Epoch   800, train loss 0.001566, train error 0.00,  test loss 5.059206, test error 52.83
# Epoch   900, train loss 0.001326, train error 0.00,  test loss 5.168262, test error 52.78
# Training model with  90 hidden variables
# Epoch     0, train loss 1.998367, train error 74.18,  test loss 1.941654, test error 75.10
# Epoch   100, train loss 0.143446, train error 0.97,  test loss 2.171083, test error 51.47
# Epoch   200, train loss 0.015139, train error 0.00,  test loss 3.234087, test error 51.47
# Epoch   300, train loss 0.006550, train error 0.00,  test loss 3.669843, test error 51.33
# Epoch   400, train loss 0.004006, train error 0.00,  test loss 3.941682, test error 51.30
# Epoch   500, train loss 0.002812, train error 0.00,  test loss 4.136579, test error 51.30
# Epoch   600, train loss 0.002138, train error 0.00,  test loss 4.291594, test error 51.38
# Epoch   700, train loss 0.001709, train error 0.00,  test loss 4.414469, test error 51.42
# Epoch   800, train loss 0.001414, train error 0.00,  test loss 4.520544, test error 51.58
# Epoch   900, train loss 0.001200, train error 0.00,  test loss 4.610709, test error 51.65
# Training model with 100 hidden variables
# Epoch     0, train loss 1.991208, train error 74.20,  test loss 1.926698, test error 75.12
# Epoch   100, train loss 0.095953, train error 0.22,  test loss 2.200737, test error 50.83
# Epoch   200, train loss 0.012381, train error 0.00,  test loss 3.031983, test error 51.00
# Epoch   300, train loss 0.005730, train error 0.00,  test loss 3.392730, test error 50.85
# Epoch   400, train loss 0.003563, train error 0.00,  test loss 3.614266, test error 50.90
# Epoch   500, train loss 0.002528, train error 0.00,  test loss 3.777249, test error 50.83
# Epoch   600, train loss 0.001936, train error 0.00,  test loss 3.905774, test error 50.92
# Epoch   700, train loss 0.001554, train error 0.00,  test loss 4.010747, test error 50.80
# Epoch   800, train loss 0.001291, train error 0.00,  test loss 4.100120, test error 50.75
# Epoch   900, train loss 0.001098, train error 0.00,  test loss 4.177436, test error 50.78
# Training model with 120 hidden variables
# Epoch     0, train loss 1.972682, train error 73.35,  test loss 1.918284, test error 75.32
# Epoch   100, train loss 0.052474, train error 0.03,  test loss 2.310318, test error 51.22
# Epoch   200, train loss 0.009312, train error 0.00,  test loss 2.918003, test error 51.33
# Epoch   300, train loss 0.004636, train error 0.00,  test loss 3.202512, test error 51.22
# Epoch   400, train loss 0.002975, train error 0.00,  test loss 3.387854, test error 51.22
# Epoch   500, train loss 0.002150, train error 0.00,  test loss 3.521126, test error 51.20
# Epoch   600, train loss 0.001665, train error 0.00,  test loss 3.628944, test error 51.17
# Epoch   700, train loss 0.001346, train error 0.00,  test loss 3.717568, test error 51.22
# Epoch   800, train loss 0.001124, train error 0.00,  test loss 3.793860, test error 51.17
# Epoch   900, train loss 0.000961, train error 0.00,  test loss 3.859979, test error 51.17
# Training model with 140 hidden variables
# Epoch     0, train loss 1.981641, train error 72.80,  test loss 1.922516, test error 73.12
# Epoch   100, train loss 0.035974, train error 0.00,  test loss 2.144625, test error 50.00
# Epoch   200, train loss 0.008102, train error 0.00,  test loss 2.624261, test error 49.78
# Epoch   300, train loss 0.004142, train error 0.00,  test loss 2.852468, test error 49.80
# Epoch   400, train loss 0.002691, train error 0.00,  test loss 3.003919, test error 50.00
# Epoch   500, train loss 0.001956, train error 0.00,  test loss 3.115217, test error 49.97
# Epoch   600, train loss 0.001520, train error 0.00,  test loss 3.203178, test error 49.97
# Epoch   700, train loss 0.001234, train error 0.00,  test loss 3.276703, test error 50.00
# Epoch   800, train loss 0.001033, train error 0.00,  test loss 3.339719, test error 50.12
# Epoch   900, train loss 0.000885, train error 0.00,  test loss 3.394246, test error 50.05
# Training model with 160 hidden variables
# Epoch     0, train loss 1.928849, train error 70.65,  test loss 1.854167, test error 72.35
# Epoch   100, train loss 0.028029, train error 0.00,  test loss 2.086566, test error 49.15
# Epoch   200, train loss 0.007088, train error 0.00,  test loss 2.483296, test error 49.55
# Epoch   300, train loss 0.003743, train error 0.00,  test loss 2.677431, test error 49.30
# Epoch   400, train loss 0.002465, train error 0.00,  test loss 2.806567, test error 49.35
# Epoch   500, train loss 0.001806, train error 0.00,  test loss 2.902708, test error 49.38
# Epoch   600, train loss 0.001410, train error 0.00,  test loss 2.980003, test error 49.45
# Epoch   700, train loss 0.001149, train error 0.00,  test loss 3.044825, test error 49.55
# Epoch   800, train loss 0.000965, train error 0.00,  test loss 3.100180, test error 49.53
# Epoch   900, train loss 0.000828, train error 0.00,  test loss 3.148643, test error 49.50
# Training model with 180 hidden variables
# Epoch     0, train loss 1.961856, train error 72.47,  test loss 1.882734, test error 72.38
# Epoch   100, train loss 0.024471, train error 0.00,  test loss 2.049970, test error 47.92
# Epoch   200, train loss 0.006539, train error 0.00,  test loss 2.406460, test error 47.30
# Epoch   300, train loss 0.003486, train error 0.00,  test loss 2.582163, test error 47.15
# Epoch   400, train loss 0.002308, train error 0.00,  test loss 2.699289, test error 47.10
# Epoch   500, train loss 0.001698, train error 0.00,  test loss 2.789189, test error 47.15
# Epoch   600, train loss 0.001330, train error 0.00,  test loss 2.860027, test error 46.92
# Epoch   700, train loss 0.001086, train error 0.00,  test loss 2.918851, test error 46.75
# Epoch   800, train loss 0.000913, train error 0.00,  test loss 2.969914, test error 46.78
# Epoch   900, train loss 0.000785, train error 0.00,  test loss 3.014543, test error 46.85
# Training model with 200 hidden variables
# Epoch     0, train loss 1.918845, train error 70.55,  test loss 1.848633, test error 72.62
# Epoch   100, train loss 0.020566, train error 0.00,  test loss 1.967663, test error 48.22
# Epoch   200, train loss 0.005916, train error 0.00,  test loss 2.264302, test error 48.38
# Epoch   300, train loss 0.003234, train error 0.00,  test loss 2.422131, test error 47.95
# Epoch   400, train loss 0.002159, train error 0.00,  test loss 2.526743, test error 47.90
# Epoch   500, train loss 0.001598, train error 0.00,  test loss 2.605659, test error 47.95
# Epoch   600, train loss 0.001256, train error 0.00,  test loss 2.669587, test error 47.83
# Epoch   700, train loss 0.001029, train error 0.00,  test loss 2.723613, test error 47.80
# Epoch   800, train loss 0.000867, train error 0.00,  test loss 2.768750, test error 47.80
# Epoch   900, train loss 0.000746, train error 0.00,  test loss 2.809105, test error 47.78
# Training model with 250 hidden variables
# Epoch     0, train loss 1.885000, train error 68.53,  test loss 1.788138, test error 70.10
# Epoch   100, train loss 0.016819, train error 0.00,  test loss 1.950673, test error 48.12
# Epoch   200, train loss 0.005308, train error 0.00,  test loss 2.201108, test error 48.03
# Epoch   300, train loss 0.002961, train error 0.00,  test loss 2.333954, test error 47.70
# Epoch   400, train loss 0.002002, train error 0.00,  test loss 2.425206, test error 47.85
# Epoch   500, train loss 0.001491, train error 0.00,  test loss 2.494909, test error 47.80
# Epoch   600, train loss 0.001178, train error 0.00,  test loss 2.550132, test error 47.62
# Epoch   700, train loss 0.000968, train error 0.00,  test loss 2.596857, test error 47.58
# Epoch   800, train loss 0.000818, train error 0.00,  test loss 2.636677, test error 47.45
# Epoch   900, train loss 0.000706, train error 0.00,  test loss 2.671635, test error 47.45
# Training model with 300 hidden variables
# Epoch     0, train loss 1.883246, train error 67.97,  test loss 1.829785, test error 70.18
# Epoch   100, train loss 0.014616, train error 0.00,  test loss 1.898967, test error 47.17
# Epoch   200, train loss 0.004847, train error 0.00,  test loss 2.121464, test error 46.88
# Epoch   300, train loss 0.002750, train error 0.00,  test loss 2.244598, test error 46.67
# Epoch   400, train loss 0.001872, train error 0.00,  test loss 2.327922, test error 46.72
# Epoch   500, train loss 0.001401, train error 0.00,  test loss 2.391405, test error 46.65
# Epoch   600, train loss 0.001110, train error 0.00,  test loss 2.443137, test error 46.58
# Epoch   700, train loss 0.000914, train error 0.00,  test loss 2.486014, test error 46.60
# Epoch   800, train loss 0.000773, train error 0.00,  test loss 2.523649, test error 46.53
# Epoch   900, train loss 0.000668, train error 0.00,  test loss 2.556675, test error 46.55
# Training model with 400 hidden variables
# Epoch     0, train loss 1.897113, train error 69.05,  test loss 1.836663, test error 70.72
# Epoch   100, train loss 0.011548, train error 0.00,  test loss 1.756792, test error 46.08
# Epoch   200, train loss 0.004134, train error 0.00,  test loss 1.924013, test error 45.72
# Epoch   300, train loss 0.002398, train error 0.00,  test loss 2.018525, test error 45.58
# Epoch   400, train loss 0.001654, train error 0.00,  test loss 2.084617, test error 45.58
# Epoch   500, train loss 0.001246, train error 0.00,  test loss 2.134898, test error 45.53
# Epoch   600, train loss 0.000993, train error 0.00,  test loss 2.175939, test error 45.42
# Epoch   700, train loss 0.000821, train error 0.00,  test loss 2.210504, test error 45.42
# Epoch   800, train loss 0.000697, train error 0.00,  test loss 2.240415, test error 45.38
# Epoch   900, train loss 0.000604, train error 0.00,  test loss 2.266615, test error 45.38

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
